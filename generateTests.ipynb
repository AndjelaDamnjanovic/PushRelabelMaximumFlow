# %%
import networkx as nx
import json

# %%
# pravimo transportnu mrezu ako graf to vec nije
def make_transport_network(transportation_network, num_nodes):
    for node in transportation_network.nodes():
        if transportation_network.in_degree(node) == 0:
            transportation_network.add_edge('101', node)
        if transportation_network.out_degree(node) == 0:
            transportation_network.add_edge(node, str(num_nodes))
        if transportation_network.has_edge(node, node):
            transportation_network.remove_edge(node, node)   
    edges = []

    for edge in transportation_network.edges.data():
        node1 = edge[0]
        node2 = edge[1]
        edges.append({'node1' : node1, 'node2' : node2, 'weight' : 1})
    return edges

# %%
def write_to_file(num_nodes, edges):
    dictionary = {
        "background": 7,
        "direction": "directed",
        "edgeColor": 8,
        "edges" : edges ,
        "hasEdges": True,
        "nodeColor": 1
    }

    file_name = "Nodes" + str(num_nodes) + ".json"
    with open(file_name, "w") as f:
        json.dump(dictionary, f)

# %%
import matplotlib.pyplot as plt
import random

def generate_transportation_network(num_nodes):
    # Generate random coordinates for nodes
    coordinates = [(random.uniform(0, 10), random.uniform(0, 10)) for _ in range(num_nodes)]
    
    # Create an empty graph
    G = nx.DiGraph()
    
    # Add nodes to the graph
    for i, (x, y) in enumerate(coordinates):
        G.add_node(i, pos=(x, y))
    
    # Add edges to the graph (connecting nearby nodes)
    for i in range(num_nodes):
        for j in range(i + 1, num_nodes):
            distance = ((coordinates[i][0] - coordinates[j][0]) ** 2 + (coordinates[i][1] - coordinates[j][1]) ** 2) ** 0.5
            # Adjust this threshold based on the desired connectivity
            if distance < 3:  
                G.add_edge(i, j)
    
    return G

# Generate a transportation network graph with 10 nodes
num_nodes = 20
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.13852813852813853

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 30
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.11693548387096774

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 40
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.1091753774680604

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 50
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.11312217194570136

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 60
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.08857747223691169

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 70
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.10289514866979656

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 80
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.10267991568804577

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 90
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.10105112279025323

# %%
# Generate a transportation network graph with 10 nodes
num_nodes = 100
transportation_network = generate_transportation_network(num_nodes)

# Visualize the graph
pos = nx.get_node_attributes(transportation_network, 'pos')
nx.draw(transportation_network, pos, with_labels=True, node_size=300, node_color='lightblue', font_size=12, font_weight='bold')
plt.show()

transportation_network.add_node("101")
transportation_network.add_node(str(num_nodes))
edges = make_transport_network(transportation_network, num_nodes)
write_to_file(num_nodes, edges)
nx.density(transportation_network)
# Out:
# 0.10240729955348477
